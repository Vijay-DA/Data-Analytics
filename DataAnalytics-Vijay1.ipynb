# %%
8+5
# Out:
# 13

# %%
print ("Python Programming")
# Out:
# Python Programming

# %%
#Calculater to do ( +,-,*,/) two number by taking user input

print("Enter First Number")
no1 = input()
number1 = int(no1)

print("Enter First Number")
no2 = input()
number2 = int(no2)

#Display Result
print("The sum of two number : ", (number1+number2))
print("The sub of two number : ", (number1-number2))
print("The multiply of two number : ", (number1*number2))
print("The division of two number : ", (number1/number2))
# Out:
# Enter First Number
#  2
# Enter First Number
#  3
# The sum of two number :  5
# The sub of two number :  -1
# The multiply of two number :  6
# The division of two number :  0.6666666666666666

# %%
#Calculator to do ( +,-,*,/) two number by taking user input

print("Enter First Number")
no1 = input()
number1 = int(no1)

print("Enter First Number")
no2 = input()
number2 = int(no2)

#Display Result
print("The sum of two number : ", (number1+number2))
print("The sub of two number : ", (number1-number2))
print("The multiply of two number : ", (number1*number2))
print("The division of two number : ", (number1/number2))
# Out:
# Enter First Number
#  12
# Enter First Number
#  2
# The sum of two number :  14
# The sub of two number :  10
# The multiply of two number :  24
# The division of two number :  6.0

# %%
# Data set of daily sales, total & average of sales

sales = [1200, 1500, 1700, 1300, 1600]
average = sum(sales)/len(sales)

print("Total Sales : ", sum(sales), " , "   "Average Sales : ", average)
# Out:
# Total Sales :  7300  , Average Sales :  1460.0
